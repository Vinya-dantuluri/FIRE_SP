# %%
import os
import pandas as pd
import datetime
from param import *

#------------------------- Path --------------------------------------------
path= "C:/Users/kameshpavanj/Desktop/Secur Data/Target"
ConPath = "C:/Users/kameshpavanj/Desktop/Secur Data/Target/Consolidated"
#------------------------ Calling folder -----------------------------------
set_folder = os.listdir(path)
Active_con = []
for folder in set_folder:
    set_file = path+"/"+folder
    for file in os.listdir(set_file):
        if file.split("_")[0] =='A':
            Active_con.append(pd.read_csv(set_file+"/"+file))
df = pd.concat(Active_con, axis=0, sort=False)
df.to_csv(ConPath+"/"+"A_KMP_AccessDB.csv", index=False)

# %%
# Out:
# [      Added Field - Active?  Field  Agreement #  \
#  0                       NaN    NaN          NaN
#  1                       NaN    NaN          NaN
#  2                       NaN    NaN          NaN
#  3                       NaN    NaN          NaN
#  4                       NaN    NaN          NaN
#  ...                     ...    ...          ...
#  1131                    NaN    NaN          NaN
#  1132                    NaN    NaN          NaN
#  1133                    NaN    NaN          NaN
#  1134                    NaN    NaN          NaN
#  1135                    NaN    NaN          NaN
#
#                                 Description Alt Agreement  \
#  0      Morguard Investments Ltd.-Sprinkler   20-1086-7BS
#  1     Morguard Investments Ltd.-Fire Alarm   20-1086-7BS
#  2          Morguard Investments Ltd.-Route   20-1086-7BS
#  3                Bronson Centre-Fire Alarm     20-1999JD
#  4                     Bronson Centre-Route     20-1999JD
#  ...                                    ...           ...
#  1131                    265 Parkdale-Route        e-mail
#  1132                 Bairn Croft-Sprinkler     20-1201JS
#  1133                 Bairn Croft-Sprinkler     20-1201JS
#  1134                      Ren's Pets-Route            RM
#  1135                       CCOC-Fire Alarm           NaN
#
#       Agreement Type (Data Pull)  Agreement Type (For Entry)  Customer  \
#  0                            AI                         NaN  100022.0
#  1                            AI                         NaN  100022.0
#  2                            AI                         NaN  100022.0
#  3                            AI                         NaN  100068.0
#  4                            AI                         NaN  100068.0
#  ...                         ...                         ...       ...
#  1131                         AI                         NaN       NaN
#  1132                         AI                         NaN       NaN
#  1133                        SAI                         NaN       NaN
#  1134                         AI                         NaN       NaN
#  1135                         AI                         NaN       NaN
#
#              Customer PO Effective Date  ... Billing Amount Tax Type  Tax Code  \
#  0     238103- Base Bldg     02/01/2021  ...            NaN      NaN       NaN
#  1     238103- Base Bldg     02/01/2021  ...            NaN      NaN       NaN
#  2     238103- Base Bldg     02/01/2021  ...            NaN      NaN       NaN
#  3                   NaN     12/01/2021  ...            NaN      NaN       NaN
#  4                   NaN     12/01/2021  ...            NaN      NaN       NaN
#  ...                 ...            ...  ...            ...      ...       ...
#  1131                NaN            NaN  ...            NaN      NaN       NaN
#  1132                NaN     11/01/2021  ...            NaN      NaN       NaN
#  1133                NaN     05/01/2021  ...            NaN      NaN       NaN
#  1134                NaN            NaN  ...            NaN      NaN       NaN
#  1135                NaN            NaN  ...            NaN      NaN       NaN
#
#        Tax Basis  Tax Amount  0.2  Deferral        Date  Amount  \
#  0           NaN         NaN  NaN       NaN  01/01/2021     NaN
#  1           NaN         NaN  NaN       NaN  01/01/2021     NaN
#  2           NaN         NaN  NaN       NaN  01/01/2021     NaN
#  3           NaN         NaN  NaN       NaN  01/01/2021     NaN
#  4           NaN         NaN  NaN       NaN  01/01/2021     NaN
#  ...         ...         ...  ...       ...         ...     ...
#  1131        NaN         NaN  NaN       NaN  01/01/2021     NaN
#  1132        NaN         NaN  NaN       NaN  01/01/2021     NaN
#  1133        NaN         NaN  NaN       NaN  01/01/2021     NaN
#  1134        NaN         NaN  NaN       NaN  01/01/2021     NaN
#  1135        NaN         NaN  NaN       NaN  01/01/2021     NaN
#
#        Should auto-populate based on Work Schedule.
#  0                                              NaN
#  1                                              NaN
#  2                                              NaN
#  3                                              NaN
#  4                                              NaN
#  ...                                            ...
#  1131                                           NaN
#  1132                                           NaN
#  1133                                           NaN
#  1134                                           NaN
#  1135                                           NaN
#
#  [1136 rows x 62 columns],       Added Field - Active?  Field  Agreement #  \
#  0                       NaN    NaN          NaN
#  1                       NaN    NaN          NaN
#  2                       NaN    NaN          NaN
#  3                       NaN    NaN          NaN
#  4                       NaN    NaN          NaN
#  ...                     ...    ...          ...
#  2279                    NaN    NaN          NaN
#  2280                    NaN    NaN          NaN
#  2281                    NaN    NaN          NaN
#  2282                    NaN    NaN          NaN
#  2283                    NaN    NaN          NaN
#
#                                              Description     Alt Agreement  \
#  0                 Inspections-COMPASS COMMERICAL REALTY  COLONNADE TENDER
#  1     Annual & periodic inspections-SIGMA ASSET MANA...  COLONNADE TENDER
#  2                 Inspections-COMPASS COMMERICAL REALTY  COLONNADE TENDER
#  3     Annual & periodic inspections-SIGMA ASSET MANA...  COLONNADE TENDER
#  4                 Inspections-COMPASS COMMERICAL REALTY  COLONNADE TENDER
#  ...                                                 ...               ...
#  2279  AI, fire alarm, emergency lighting-OTTAWA-CARL...     TENDER 19-051
#  2280  AI, fire alarm, emergency lighting-OTTAWA-CARL...     TENDER 19-051
#  2281  AI, fire alarm, emergency lighting-OTTAWA-CARL...     TENDER 19-051
#  2282  AI, fire alarm, emergency lighting-OTTAWA-CARL...     TENDER 19-051
#  2283  AI, fire alarm, emergency lighting-OTTAWA-CARL...     TENDER 19-051
#
#       Agreement Type (Data Pull) Agreement Type (For Entry)  Customer  \
#  0                           NaN                         BI       NaN
#  1                           NaN                         BI       NaN
#  2                           NaN                         MI       NaN
#  3                           NaN                         MI       NaN
#  4                           NaN                         BI       NaN
#  ...                         ...                        ...       ...
#  2279                        NaN                         AI       NaN
#  2280                        NaN                         AI       NaN
#  2281                        NaN                         AI       NaN
#  2282                        NaN                         AI       NaN
#  2283                        NaN                         AI       NaN
#
#        Customer PO Effective Date  ... Billing Amount Tax Type  Tax Code  \
#  0             NaN     11/28/2021  ...            NaN      NaN       NaN
#  1             NaN     01/14/2021  ...            NaN      NaN       NaN
#  2             NaN     11/28/2021  ...            NaN      NaN       NaN
#  3             NaN     01/14/2021  ...            NaN      NaN       NaN
#  4             NaN     11/28/2021  ...            NaN      NaN       NaN
#  ...           ...            ...  ...            ...      ...       ...
#  2279          NaN     06/27/2021  ...            NaN      NaN       NaN
#  2280          NaN     06/27/2021  ...            NaN      NaN       NaN
#  2281          NaN     06/27/2021  ...            NaN      NaN       NaN
#  2282          NaN     06/27/2021  ...            NaN      NaN       NaN
#  2283          NaN     06/27/2021  ...            NaN      NaN       NaN
#
#        Tax Basis  Tax Amount  0.2  Deferral        Date  Amount  \
#  0           NaN         NaN  NaN       NaN  01/01/2021     NaN
#  1           NaN         NaN  NaN       NaN  01/01/2021     NaN
#  2           NaN         NaN  NaN       NaN  01/01/2021     NaN
#  3           NaN         NaN  NaN       NaN  01/01/2021     NaN
#  4           NaN         NaN  NaN       NaN  01/01/2021     NaN
#  ...         ...         ...  ...       ...         ...     ...
#  2279        NaN         NaN  NaN       NaN  01/01/2021     NaN
#  2280        NaN         NaN  NaN       NaN  01/01/2021     NaN
#  2281        NaN         NaN  NaN       NaN  01/01/2021     NaN
#  2282        NaN         NaN  NaN       NaN  01/01/2021     NaN
#  2283        NaN         NaN  NaN       NaN  01/01/2021     NaN
#
#        Should auto-populate based on Work Schedule.
#  0                                              NaN
#  1                                              NaN
#  2                                              NaN
#  3                                              NaN
#  4                                              NaN
#  ...                                            ...
#  2279                                           NaN
#  2280                                           NaN
#  2281                                           NaN
#  2282                                           NaN
#  2283                                           NaN
#
#  [2284 rows x 62 columns],       Added Field - Active?  Field  Agreement #  \
#  0                       NaN    NaN          NaN
#  1                       NaN    NaN          NaN
#  2                       NaN    NaN          NaN
#  3                       NaN    NaN          NaN
#  4                       NaN    NaN          NaN
#  ...                     ...    ...          ...
#  2692                    NaN    NaN          NaN
#  2693                    NaN    NaN          NaN
#  2694                    NaN    NaN          NaN
#  2695                    NaN    NaN          NaN
#  2696                    NaN    NaN          NaN
#
#                                            Description Alt Agreement  \
#  0     FIRE ALARM AI,PERIODIC-OTTAWA COMMUNITY HOUSING      0-100013
#  1     FIRE ALARM AI,PERIODIC-OTTAWA COMMUNITY HOUSING      0-100013
#  2     FIRE ALARM AI,PERIODIC-OTTAWA COMMUNITY HOUSING      0-100013
#  3     FIRE ALARM AI,PERIODIC-OTTAWA COMMUNITY HOUSING      0-100013
#  4     FIRE ALARM AI,PERIODIC-OTTAWA COMMUNITY HOUSING      0-100013
#  ...                                               ...           ...
#  2692    AI LSA&CO (in units)-OTTAWA COMMUNITY HOUSING      0-100014
#  2693    AI LSA&CO (in units)-OTTAWA COMMUNITY HOUSING      0-100014
#  2694    AI LSA&CO (in units)-OTTAWA COMMUNITY HOUSING      0-100014
#  2695    AI LSA&CO (in units)-OTTAWA COMMUNITY HOUSING      0-100014
#  2696    AI LSA&CO (in units)-OTTAWA COMMUNITY HOUSING      0-100014
#
#       Agreement Type (Data Pull) Agreement Type (For Entry)  Customer  \
#  0                    S164-B0002                         MI    100051
#  1                    S164-B0002                         MI    100051
#  2                    S164-B0002                        SAI    100051
#  3                    S164-B0002                         MI    100051
#  4                    S164-B0002                         MI    100051
#  ...                         ...                        ...       ...
#  2692                        NaN                         AI    100052
#  2693                 S073-B0667                         AI    100052
#  2694                 S073-B0031                         AI    100052
#  2695                        NaN                         AI    100052
#  2696                        NaN                         AI    100052
#
#        Customer PO Effective Date  ... Billing Amount Tax Type  Tax Code  \
#  0             NaN     06/15/2021  ...            NaN      NaN       NaN
#  1             NaN     06/15/2021  ...            NaN      NaN       NaN
#  2             NaN     06/15/2021  ...            NaN      NaN       NaN
#  3             NaN     06/15/2021  ...            NaN      NaN       NaN
#  4             NaN     06/15/2021  ...            NaN      NaN       NaN
#  ...           ...            ...  ...            ...      ...       ...
#  2692          NaN     06/15/2021  ...            NaN      NaN       NaN
#  2693          NaN     06/15/2021  ...            NaN      NaN       NaN
#  2694          NaN     06/15/2021  ...            NaN      NaN       NaN
#  2695          NaN     06/15/2021  ...            NaN      NaN       NaN
#  2696          NaN     06/15/2021  ...            NaN      NaN       NaN
#
#        Tax Basis  Tax Amount  0.2  Deferral        Date  Amount  \
#  0           NaN         NaN  NaN       NaN  01/01/2021     NaN
#  1           NaN         NaN  NaN       NaN  01/01/2021     NaN
#  2           NaN         NaN  NaN       NaN  01/01/2021     NaN
#  3           NaN         NaN  NaN       NaN  01/01/2021     NaN
#  4           NaN         NaN  NaN       NaN  01/01/2021     NaN
#  ...         ...         ...  ...       ...         ...     ...
#  2692        NaN         NaN  NaN       NaN  01/01/2021     NaN
#  2693        NaN         NaN  NaN       NaN  01/01/2021     NaN
#  2694        NaN         NaN  NaN       NaN  01/01/2021     NaN
#  2695        NaN         NaN  NaN       NaN  01/01/2021     NaN
#  2696        NaN         NaN  NaN       NaN  01/01/2021     NaN
#
#        Should auto-populate based on Work Schedule.
#  0                                              NaN
#  1                                              NaN
#  2                                              NaN
#  3                                              NaN
#  4                                              NaN
#  ...                                            ...
#  2692                                           NaN
#  2693                                           NaN
#  2694                                           NaN
#  2695                                           NaN
#  2696                                           NaN
#
#  [2697 rows x 62 columns]]
